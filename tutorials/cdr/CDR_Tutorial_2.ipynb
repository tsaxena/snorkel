# %% [markdown]
# # Chemical-Disease Relation (CDR) Tutorial
#
# In this example, we'll be writing an application to extract *mentions of* **chemical-induced-disease relationships** from Pubmed abstracts, as per the [BioCreative CDR Challenge](http://www.biocreative.org/resources/corpora/biocreative-v-cdr-corpus/).  This tutorial will show off some of the more advanced features of Snorkel, so we'll assume you've followed the Intro tutorial.

# %% [markdown]
# Let's start by reloading from the last notebook.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os

# TO USE A DATABASE OTHER THAN SQLITE, USE THIS LINE
# Note that this is necessary for parallel execution amongst other things...
os.environ['SNORKELDB'] = 'postgres:///cdr-structure-learning-2'

from snorkel import SnorkelSession

session = SnorkelSession()

# %%
from snorkel.models import candidate_subclass

ChemicalDisease = candidate_subclass('ChemicalDisease', ['chemical', 'disease'])

train_cands = session.query(ChemicalDisease).filter(ChemicalDisease.split == 0).all()
dev_cands = session.query(ChemicalDisease).filter(ChemicalDisease.split == 1).all()

# %%
print len(train_cands)
print len(dev_cands)
# Out:
# 34283
# 888

# %% [markdown]
# # Part III: Writing LFs
#
# This tutorial features some more advanced LFs than the intro tutorial, with more focus on distant supervision and dependencies between LFs.

# %% [markdown]
# ### Distant supervision approaches

# %% [markdown]
# We'll use the [Comparative Toxicogenomics Database](http://ctdbase.org/) (CTD) for distant supervision. The CTD lists chemical-condition entity pairs under three categories: therapy, marker, and unspecified. Therapy means the chemical treats the condition, marker means the chemical is typically present with the condition, and unspecified is...unspecified. We can write LFs based on these categories.

# %% [markdown]
# ### Note: Mapping `snorkel-biocorpus-new` CIDS to common format
#
# In particular, **we don't yet handle the CHEBI ones!! (TODO!)**:

# %%
def map_cids(cids):
    """For now, return MESH only"""
    return tuple([cid[5:] if cid.startswith("MESH:") else None for cid in cids])

# %%
import bz2
import cPickle

with bz2.BZ2File('data/ctd.pkl.bz2', 'rb') as ctd_f:
    ctd_unspecified, ctd_therapy, ctd_marker = cPickle.load(ctd_f)

# %%
def cand_in_ctd_unspecified(c):
    return 1 if map_cids(c.get_cids()) in ctd_unspecified else 0

def cand_in_ctd_therapy(c):
    return 1 if map_cids(c.get_cids()) in ctd_therapy else 0

def cand_in_ctd_marker(c):
    return 1 if map_cids(c.get_cids()) in ctd_marker else 0

# %%
def LF_in_ctd_unspecified(c):
    return -1 * cand_in_ctd_unspecified(c)

def LF_in_ctd_therapy(c):
    return -1 * cand_in_ctd_therapy(c)

def LF_in_ctd_marker(c):
    return cand_in_ctd_marker(c)

# %% [markdown]
# ### Text pattern approaches
#
# Now we'll use some LF helpers to create LFs based on indicative text patterns. We came up with these rules by using the viewer to examine training candidates and noting frequent patterns.

# %%
import re
from snorkel.lf_helpers import (
    get_tagged_text,
    rule_regex_search_tagged_text,
    rule_regex_search_btw_AB,
    rule_regex_search_btw_BA,
    rule_regex_search_before_A,
    rule_regex_search_before_B,
)

# List to parenthetical
def ltp(x):
    return '(' + '|'.join(x) + ')'

def LF_induce(c):
    return 1 if re.search(r'{{A}}.{0,20}induc.{0,20}{{B}}', get_tagged_text(c), flags=re.I) else 0

causal_past = ['induced', 'caused', 'due']
def LF_d_induced_by_c(c):
    return rule_regex_search_btw_BA(c, '.{0,50}' + ltp(causal_past) + '.{0,9}(by|to).{0,50}', 1)
def LF_d_induced_by_c_tight(c):
    return rule_regex_search_btw_BA(c, '.{0,50}' + ltp(causal_past) + ' (by|to) ', 1)

def LF_induce_name(c):
    return 1 if 'induc' in c.chemical.get_span().lower() else 0     

causal = ['cause[sd]?', 'induce[sd]?', 'associated with']
def LF_c_cause_d(c):
    return 1 if (
        re.search(r'{{A}}.{0,50} ' + ltp(causal) + '.{0,50}{{B}}', get_tagged_text(c), re.I)
        and not re.search('{{A}}.{0,50}(not|no).{0,20}' + ltp(causal) + '.{0,50}{{B}}', get_tagged_text(c), re.I)
    ) else 0

treat = ['treat', 'effective', 'prevent', 'resistant', 'slow', 'promise', 'therap']
def LF_d_treat_c(c):
    return rule_regex_search_btw_BA(c, '.{0,50}' + ltp(treat) + '.{0,50}', -1)
def LF_c_treat_d(c):
    return rule_regex_search_btw_AB(c, '.{0,50}' + ltp(treat) + '.{0,50}', -1)
def LF_treat_d(c):
    return rule_regex_search_before_B(c, ltp(treat) + '.{0,50}', -1)
def LF_c_treat_d_wide(c):
    return rule_regex_search_btw_AB(c, '.{0,200}' + ltp(treat) + '.{0,200}', -1)

def LF_c_d(c):
    return 1 if ('{{A}} {{B}}' in get_tagged_text(c)) else 0

def LF_c_induced_d(c):
    return 1 if (
        ('{{A}} {{B}}' in get_tagged_text(c)) and 
        (('-induc' in c[0].get_span().lower()) or ('-assoc' in c[0].get_span().lower()))
        ) else 0

def LF_improve_before_disease(c):
    return rule_regex_search_before_B(c, 'improv.*', -1)

pat_terms = ['in a patient with ', 'in patients with']
def LF_in_patient_with(c):
    return -1 if re.search(ltp(pat_terms) + '{{B}}', get_tagged_text(c), flags=re.I) else 0

uncertain = ['combin', 'possible', 'unlikely']
def LF_uncertain(c):
    return rule_regex_search_before_A(c, ltp(uncertain) + '.*', -1)

def LF_induced_other(c):
    return rule_regex_search_tagged_text(c, '{{A}}.{20,1000}-induced {{B}}', -1)

def LF_far_c_d(c):
    return rule_regex_search_btw_AB(c, '.{100,5000}', -1)

def LF_far_d_c(c):
    return rule_regex_search_btw_BA(c, '.{100,5000}', -1)

def LF_risk_d(c):
    return rule_regex_search_before_B(c, 'risk of ', 1)

def LF_develop_d_following_c(c):
    return 1 if re.search(r'develop.{0,25}{{B}}.{0,25}following.{0,25}{{A}}', get_tagged_text(c), flags=re.I) else 0

procedure, following = ['inject', 'administrat'], ['following']
def LF_d_following_c(c):
    return 1 if re.search('{{B}}.{0,50}' + ltp(following) + '.{0,20}{{A}}.{0,50}' + ltp(procedure), get_tagged_text(c), flags=re.I) else 0

def LF_measure(c):
    return -1 if re.search('measur.{0,75}{{A}}', get_tagged_text(c), flags=re.I) else 0

def LF_level(c):
    return -1 if re.search('{{A}}.{0,25} level', get_tagged_text(c), flags=re.I) else 0

def LF_neg_d(c):
    return -1 if re.search('(none|not|no) .{0,25}{{B}}', get_tagged_text(c), flags=re.I) else 0

WEAK_PHRASES = ['none', 'although', 'was carried out', 'was conducted',
                'seems', 'suggests', 'risk', 'implicated',
               'the aim', 'to (investigate|assess|study)']

WEAK_RGX = r'|'.join(WEAK_PHRASES)

def LF_weak_assertions(c):
    return -1 if re.search(WEAK_RGX, get_tagged_text(c), flags=re.I) else 0
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:1173: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %% [markdown]
# ### Composite LFs
#
# The following LFs take some of the strongest distant supervision and text pattern LFs, and combine them to form more specific LFs. These LFs introduce some obvious dependencies within the LF set, which we will model later.

# %%
def LF_ctd_marker_c_d(c):
    return LF_c_d(c) * cand_in_ctd_marker(c)

def LF_ctd_marker_induce(c):
    return (LF_c_induced_d(c) or LF_d_induced_by_c_tight(c)) * cand_in_ctd_marker(c)

def LF_ctd_therapy_treat(c):
    return LF_c_treat_d_wide(c) * cand_in_ctd_therapy(c)

def LF_ctd_unspecified_treat(c):
    return LF_c_treat_d_wide(c) * cand_in_ctd_unspecified(c)

def LF_ctd_unspecified_induce(c):
    return (LF_c_induced_d(c) or LF_d_induced_by_c_tight(c)) * cand_in_ctd_unspecified(c)

# %% [markdown]
# ### Rules based on context hierarchy
#
# These last two rules will make use of the context hierarchy. The first checks if there is a chemical mention much closer to the candidate's disease mention than the candidate's chemical mention. The second does the analog for diseases.

# %%
def LF_closer_chem(c):
    # Get distance between chemical and disease
    chem_start, chem_end = c.chemical.get_word_start(), c.chemical.get_word_end()
    dis_start, dis_end = c.disease.get_word_start(), c.disease.get_word_end()
    if dis_start < chem_start:
        dist = chem_start - dis_end
    else:
        dist = dis_start - chem_end
    # Try to find chemical closer than @dist/2 in either direction
    sent = c.get_parent()
    closest_other_chem = float('inf')
    for i in range(dis_end, min(len(sent.words), dis_end + dist / 2)):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Chemical' and cid != sent.entity_cids[chem_start]:
            return -1
    for i in range(max(0, dis_start - dist / 2), dis_start):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Chemical' and cid != sent.entity_cids[chem_start]:
            return -1
    return 0

def LF_closer_dis(c):
    # Get distance between chemical and disease
    chem_start, chem_end = c.chemical.get_word_start(), c.chemical.get_word_end()
    dis_start, dis_end = c.disease.get_word_start(), c.disease.get_word_end()
    if dis_start < chem_start:
        dist = chem_start - dis_end
    else:
        dist = dis_start - chem_end
    # Try to find chemical disease than @dist/8 in either direction
    sent = c.get_parent()
    for i in range(chem_end, min(len(sent.words), chem_end + dist / 8)):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Disease' and cid != sent.entity_cids[dis_start]:
            return -1
    for i in range(max(0, chem_start - dist / 8), chem_start):
        et, cid = sent.entity_types[i], sent.entity_cids[i]
        if et == 'Disease' and cid != sent.entity_cids[dis_start]:
            return -1
    return 0

# %% [markdown]
# ### Running the LFs on the training set

# %%
LFs = [
    LF_c_cause_d,
    LF_c_d,
    LF_c_induced_d,
    LF_c_treat_d,
    LF_c_treat_d_wide,
    LF_closer_chem,
    LF_closer_dis,
    LF_ctd_marker_c_d,
    LF_ctd_marker_induce,
    LF_ctd_therapy_treat,
    LF_ctd_unspecified_treat,
    LF_ctd_unspecified_induce,
    LF_d_following_c,
    LF_d_induced_by_c,
    LF_d_induced_by_c_tight,
    LF_d_treat_c,
    LF_develop_d_following_c,
    LF_far_c_d,
    LF_far_d_c,
    LF_improve_before_disease,
    LF_in_ctd_therapy,
    LF_in_ctd_marker,
    LF_in_patient_with,
    LF_induce,
    LF_induce_name,
    LF_induced_other,
    LF_level,
    LF_measure,
    LF_neg_d,
    LF_risk_d,
    LF_treat_d,
    LF_uncertain,
    LF_weak_assertions,
]

# %%
from snorkel.annotations import LabelAnnotator
labeler = LabelAnnotator(f=LFs)

# %%
# %time L_train = labeler.apply(split=0, parallelism=20)
L_train

# %% [markdown]
# ### Or, reload labels here:

# %%
# %time L_train = labeler.load_matrix(session, split=0)
L_train
# Out:
# CPU times: user 736 ms, sys: 44 ms, total: 780 ms
# Wall time: 826 ms
# <34283x33 sparse matrix of type '<type 'numpy.float64'>'
# 	with 36569 stored elements in Compressed Sparse Row format>

# %%
L_train.lf_stats(session)

# %% [markdown]
# # Part IV: Training the generative model
#
# As mentioned above, we want to include the dependencies between our LFs when training the generative model. Snorkel makes it easy to do this! `DependencySelector` runs a fast structure learning algorithm over the matrix of LF outputs to identify a set of likely dependencies. We can see that these match up with our prior knowledge. For example, it identified a "reinforcing" dependency between `LF_c_induced_d` and `LF_ctd_marker_induce`. Recall that we constructed the latter using the former.

# %% [markdown]
# ## For testing without deps

# %%
deps = set()

# %% [markdown]
# ### For testing with deps

# %%
from snorkel.learning.structure import DependencySelector
ds = DependencySelector()
deps = ds.select(L_train, threshold=1.0/3.0)
deps

# %% [markdown]
# ### Grid search over deps

# %%
import numpy as np
deps_gs = []
threshs = np.arange(0.1, 0.4, 0.025)
for thresh in threshs:
    ds   = DependencySelector()
    deps = ds.select(L_train, threshold=thresh)
    print len(deps)
    deps_gs.append(deps)

# %%
plt.plot(threshs, map(len, deps_gs))

# %%
deps = deps_gs[2]
len(deps)

# %% [markdown]
# Now we'll train the generative model, using the `deps` argument to account for the learned dependencies. We'll also model LF propensity here, unlike the intro tutorial. In addition to learning the accuracies of the LFs, this also learns their likelihood of labeling an example.

# %%
from snorkel.learning import GenerativeModel

gen_model = GenerativeModel(lf_prior=True, lf_propensity=True)
gen_model.train(
    L_train, deps=deps, epochs=15, decay=1.0, step_size=1.0 / L_train.shape[0], reg_type=2, reg_param=0.00001, verbose=False
)

# %%
train_marginals = gen_model.marginals(L_train)

# %%
import matplotlib.pyplot as plt
plt.hist(train_marginals, bins=20)
plt.show()

# %%
gen_model.weights.lf_accuracy()
# Out:
# array([ 0.50135146,  0.50162753,  0.50039733,  0.50460455,  0.50575672,
#         0.50225507,  0.49842556,  0.49925034,  0.50062932,  0.50419761,
#         0.50400572,  0.49904501,  0.49824681,  0.49950527,  0.49929206,
#         0.50049792,  0.50098536,  0.50486155,  0.49724853,  0.49998286,
#         0.50467288,  0.49794367,  0.50099389,  0.49940845,  0.49990718,
#         0.50025786,  0.50325795,  0.50216299,  0.50155161,  0.50236785,
#         0.5003118 ,  0.49961502,  0.50188433])

# %%
from snorkel.annotations import save_marginals
save_marginals(session, L_train, train_marginals)
# Out:
# Saved 34283 training marginals

# %% [markdown]
# ### Checking performance against development set labels
#
# Finally, we'll run the labeler on the development set, load in some external labels, then evaluate the LF performance. The external labels are applied via a small script for convenience. It maps the document-level relation annotations found in the CDR file to mention-level labels. Note that these will not be perfect, although they are pretty good. If we wanted to keep iterating, we could use `snorkel.lf_helpers.test_LF` against the dev set, or look at some false positive and false negative candidates.

# %%
from load_external_annotations import load_external_labels
load_external_labels(session, ChemicalDisease, split=1, annotator='gold')
# Out:
# AnnotatorLabels created: 0

# %%
from snorkel.annotations import load_gold_labels
L_gold_dev = load_gold_labels(session, annotator_name='gold', split=1)
L_gold_dev
# Out:
# <888x1 sparse matrix of type '<type 'numpy.float64'>'
# 	with 888 stored elements in Compressed Sparse Row format>

# %%
L_dev = labeler.apply(split=1)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%

# %%
gen_model.score(session, L_dev, L_gold_dev)
# Out:
# ========================================
# Scores (Un-adjusted)
# ========================================
# Pos. class accuracy: 0.274
# Neg. class accuracy: 0.914
# Precision            0.614
# Recall               0.274
# F1                   0.379
# ----------------------------------------
# TP: 81 | FP: 51 | TN: 541 | FN: 215
# ========================================
# ({ChemicalDisease(Span("morphine-induced", sentence=7103, chars=[113,128], words=[22,22]), Span("spastic paraparesis", sentence=7103, chars=[130,148], words=[23,24])),
#   ChemicalDisease(Span("Cocaine-induced", sentence=7230, chars=[0,14], words=[0,0]), Span("seizures", sentence=7230, chars=[26,33], words=[2,2])),
#   ChemicalDisease(Span("nicotine", sentence=9957, chars=[17,24], words=[3,3]), Span("catalepsy", sentence=9957, chars=[51,59], words=[7,7])),
#   ChemicalDisease(Span("morphine", sentence=7107, chars=[28,35], words=[5,5]), Span("spastic paraparesis", sentence=7107, chars=[45,63], words=[7,8])),
#   ChemicalDisease(Span("levodopa-induced", sentence=9663, chars=[88,103], words=[12,12]), Span("involuntary movements", sentence=9663, chars=[115,135], words=[15,16])),
#   ChemicalDisease(Span("Quinidine", sentence=9882, chars=[0,8], words=[0,0]), Span("hepatitis", sentence=9882, chars=[10,18], words=[1,1])),
#   ChemicalDisease(Span("nitric oxide-induced", sentence=8572, chars=[46,65], words=[5,6]), Span("headache", sentence=8572, chars=[67,74], words=[7,7])),
#   ChemicalDisease(Span("ethinyl estradiol-induced", sentence=7241, chars=[78,102], words=[9,10]), Span("cholestasis", sentence=7241, chars=[104,114], words=[11,11])),
#   ChemicalDisease(Span("Haloperidol", sentence=6595, chars=[0,10], words=[0,0]), Span("akathisia", sentence=6595, chars=[68,76], words=[12,12])),
#   ChemicalDisease(Span("dobutamine-induced", sentence=9519, chars=[76,93], words=[10,10]), Span("myocardial ischemia", sentence=9519, chars=[95,113], words=[11,12])),
#   ChemicalDisease(Span("levodopa-induced", sentence=9662, chars=[12,27], words=[2,2]), Span("involuntary movements", sentence=9662, chars=[29,49], words=[3,4])),
#   ChemicalDisease(Span("scopolamine-induced", sentence=10564, chars=[61,79], words=[11,11]), Span("impairment in word recall", sentence=10564, chars=[81,105], words=[12,15])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=6169, chars=[173,188], words=[27,27]), Span("hemorrhagic cystitis", sentence=6169, chars=[202,221], words=[30,31])),
#   ChemicalDisease(Span("scopolamine-induced", sentence=10561, chars=[97,115], words=[15,15]), Span("impairment in word recall", sentence=10561, chars=[117,141], words=[16,19])),
#   ChemicalDisease(Span("diltiazem", sentence=7349, chars=[63,71], words=[11,11]), Span("overdose", sentence=7349, chars=[73,80], words=[12,12])),
#   ChemicalDisease(Span("lindane", sentence=8860, chars=[177,183], words=[29,29]), Span("convulsions", sentence=8860, chars=[193,203], words=[31,31])),
#   ChemicalDisease(Span("lindane", sentence=8860, chars=[368,374], words=[61,61]), Span("convulsions", sentence=8860, chars=[384,394], words=[63,63])),
#   ChemicalDisease(Span("warfarin", sentence=6834, chars=[108,115], words=[13,13]), Span("haemopericardium and gastrointestinal haemorrhage", sentence=6834, chars=[6,54], words=[1,4])),
#   ChemicalDisease(Span("amphetamine-induced", sentence=10127, chars=[109,127], words=[22,22]), Span("hyperactivity", sentence=10127, chars=[129,141], words=[23,23])),
#   ChemicalDisease(Span("METH-induced", sentence=6259, chars=[53,64], words=[8,8]), Span("aggressiveness", sentence=6259, chars=[17,30], words=[3,3])),
#   ChemicalDisease(Span("lidocaine-induced", sentence=9511, chars=[32,48], words=[6,6]), Span("convulsion", sentence=9511, chars=[50,59], words=[7,7])),
#   ChemicalDisease(Span("lidocaine-induced", sentence=9512, chars=[148,164], words=[26,26]), Span("convulsions", sentence=9512, chars=[166,176], words=[27,27])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8417, chars=[169,181], words=[25,25]), Span("urticaria/angioedema", sentence=8417, chars=[183,202], words=[26,26])),
#   ChemicalDisease(Span("morphine-induced", sentence=9955, chars=[25,40], words=[3,3]), Span("catalepsy", sentence=9955, chars=[42,50], words=[4,4])),
#   ChemicalDisease(Span("isoflurane-induced", sentence=8979, chars=[49,66], words=[6,6]), Span("hypotension", sentence=8979, chars=[68,78], words=[7,7])),
#   ChemicalDisease(Span("morphine-induced", sentence=7106, chars=[83,98], words=[10,10]), Span("spastic paraparesis", sentence=7106, chars=[100,118], words=[11,12])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8422, chars=[109,121], words=[21,21]), Span("angioedema", sentence=8422, chars=[147,156], words=[24,24])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8419, chars=[130,142], words=[18,18]), Span("urticaria/angioedema", sentence=8419, chars=[144,163], words=[19,19])),
#   ChemicalDisease(Span("bendrofluazide-induced", sentence=8730, chars=[16,37], words=[2,2]), Span("hypokalemia", sentence=8730, chars=[39,49], words=[3,3])),
#   ChemicalDisease(Span("diltiazem", sentence=7341, chars=[39,47], words=[5,5]), Span("overdose", sentence=7341, chars=[49,56], words=[6,6])),
#   ChemicalDisease(Span("doxorubicin-induced", sentence=6358, chars=[92,110], words=[15,15]), Span("cardiomyopathy", sentence=6358, chars=[112,125], words=[16,16])),
#   ChemicalDisease(Span("PTU-associated", sentence=7939, chars=[0,13], words=[0,0]), Span("vasculitis", sentence=7939, chars=[15,24], words=[1,1])),
#   ChemicalDisease(Span("dipyridamole-induced", sentence=6444, chars=[7,26], words=[1,1]), Span("hyperemia", sentence=6444, chars=[28,36], words=[2,2])),
#   ChemicalDisease(Span("dipyridamole-induced", sentence=6445, chars=[105,124], words=[24,24]), Span("hyperemia", sentence=6445, chars=[126,134], words=[25,25])),
#   ChemicalDisease(Span("isoflurane-induced", sentence=8980, chars=[14,31], words=[3,3]), Span("hypotension", sentence=8980, chars=[33,43], words=[4,4])),
#   ChemicalDisease(Span("Etoposide-related", sentence=8001, chars=[0,16], words=[0,0]), Span("myocardial infarction", sentence=8001, chars=[18,38], words=[1,2])),
#   ChemicalDisease(Span("milrinone-induced", sentence=9316, chars=[32,48], words=[5,5]), Span("hypotension", sentence=9316, chars=[50,60], words=[6,6])),
#   ChemicalDisease(Span("isoflurane-induced", sentence=8987, chars=[68,85], words=[9,9]), Span("hypotension", sentence=8987, chars=[87,97], words=[10,10])),
#   ChemicalDisease(Span("levodopa-induced", sentence=9666, chars=[46,61], words=[8,8]), Span("dyskinesias", sentence=9666, chars=[63,73], words=[9,9])),
#   ChemicalDisease(Span("nomifensine", sentence=10128, chars=[29,39], words=[4,4]), Span("hyperactivity", sentence=10128, chars=[4,16], words=[1,1])),
#   ChemicalDisease(Span("NO)", sentence=8573, chars=[40,42], words=[8,9]), Span("headache", sentence=8573, chars=[52,59], words=[11,11])),
#   ChemicalDisease(Span("azathioprine-induced", sentence=8978, chars=[66,85], words=[12,12]), Span("cholestasis", sentence=8978, chars=[87,97], words=[13,13])),
#   ChemicalDisease(Span("azathioprine-induced", sentence=8978, chars=[66,85], words=[12,12]), Span("bile duct injury", sentence=8978, chars=[140,155], words=[19,21])),
#   ChemicalDisease(Span("puromycin aminonucleoside", sentence=7054, chars=[38,62], words=[5,6]), Span("nephrosis", sentence=7054, chars=[64,72], words=[7,7])),
#   ChemicalDisease(Span("aconitine", sentence=8301, chars=[119,127], words=[17,17]), Span("arrhythmic", sentence=8301, chars=[71,80], words=[9,9])),
#   ChemicalDisease(Span("puromycin aminonucleoside-induced", sentence=7055, chars=[101,133], words=[17,18]), Span("nephrosis", sentence=7055, chars=[135,143], words=[19,19])),
#   ChemicalDisease(Span("reserpine", sentence=9131, chars=[81,89], words=[13,13]), Span("tremor", sentence=9131, chars=[63,68], words=[10,10])),
#   ChemicalDisease(Span("reserpine", sentence=9131, chars=[81,89], words=[13,13]), Span("catalepsy", sentence=9131, chars=[49,57], words=[8,8])),
#   ChemicalDisease(Span("levodopa-induced", sentence=7793, chars=[13,28], words=[2,2]), Span("dyskinesias", sentence=7793, chars=[30,40], words=[3,3])),
#   ChemicalDisease(Span("epsilon-aminocaproic acid", sentence=6969, chars=[8,32], words=[2,3]), Span("myopathy", sentence=6969, chars=[48,55], words=[8,8])),
#   ChemicalDisease(Span("EACA)", sentence=6969, chars=[35,39], words=[5,6]), Span("myopathy", sentence=6969, chars=[48,55], words=[8,8])),
#   ChemicalDisease(Span("succinylcholine", sentence=8102, chars=[35,49], words=[6,6]), Span("apnoea", sentence=8102, chars=[51,56], words=[7,7])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8415, chars=[60,72], words=[8,8]), Span("urticaria/angioedema", sentence=8415, chars=[74,93], words=[9,9])),
#   ChemicalDisease(Span("quinidine", sentence=9887, chars=[35,43], words=[6,6]), Span("hepatotoxicity", sentence=9887, chars=[45,58], words=[7,7])),
#   ChemicalDisease(Span("cocaine-induced", sentence=7337, chars=[201,215], words=[30,30]), Span("psychosis", sentence=7337, chars=[217,225], words=[31,31])),
#   ChemicalDisease(Span("haloperidol-induced", sentence=6811, chars=[44,62], words=[8,8]), Span("catalepsy", sentence=6811, chars=[64,72], words=[9,9])),
#   ChemicalDisease(Span("lidocaine-induced", sentence=9518, chars=[65,81], words=[11,11]), Span("convulsions", sentence=9518, chars=[83,93], words=[12,12])),
#   ChemicalDisease(Span("reserpine", sentence=9127, chars=[154,162], words=[26,26]), Span("catalepsy", sentence=9127, chars=[133,141], words=[23,23])),
#   ChemicalDisease(Span("NO-induced", sentence=8581, chars=[33,42], words=[5,5]), Span("headache", sentence=8581, chars=[54,61], words=[7,7])),
#   ChemicalDisease(Span("nicotine", sentence=9960, chars=[125,132], words=[16,16]), Span("catalepsy", sentence=9960, chars=[90,98], words=[11,11])),
#   ChemicalDisease(Span("morphine", sentence=9960, chars=[111,118], words=[14,14]), Span("catalepsy", sentence=9960, chars=[90,98], words=[11,11])),
#   ChemicalDisease(Span("adrenaline-induced", sentence=9358, chars=[37,54], words=[6,6]), Span("bradycardia", sentence=9358, chars=[63,73], words=[8,8])),
#   ChemicalDisease(Span("morphine", sentence=9962, chars=[22,29], words=[4,4]), Span("catalepsy", sentence=9962, chars=[31,39], words=[5,5])),
#   ChemicalDisease(Span("methadone", sentence=9472, chars=[15,23], words=[4,4]), Span("syncope", sentence=9472, chars=[98,104], words=[23,23])),
#   ChemicalDisease(Span("Methadone", sentence=9473, chars=[13,21], words=[2,2]), Span("QT prolongation", sentence=9473, chars=[42,56], words=[6,7])),
#   ChemicalDisease(Span("Methadone", sentence=9473, chars=[13,21], words=[2,2]), Span("syncope", sentence=9473, chars=[82,88], words=[12,12])),
#   ChemicalDisease(Span("succinylcholine", sentence=8096, chars=[35,49], words=[6,6]), Span("apnoea", sentence=8096, chars=[51,56], words=[7,7])),
#   ChemicalDisease(Span("Cefotetan-induced", sentence=9000, chars=[0,16], words=[0,0]), Span("hemolytic anemia", sentence=9000, chars=[25,40], words=[2,3])),
#   ChemicalDisease(Span("Oxacillin", sentence=9931, chars=[0,8], words=[0,0]), Span("leucocytoclastic vasculitis", sentence=9931, chars=[60,86], words=[10,11])),
#   ChemicalDisease(Span("ouabain-induced", sentence=8296, chars=[144,158], words=[22,22]), Span("arrhythmia", sentence=8296, chars=[171,180], words=[25,25])),
#   ChemicalDisease(Span("reserpine", sentence=9130, chars=[19,27], words=[5,5]), Span("catalepsy", sentence=9130, chars=[61,69], words=[11,11])),
#   ChemicalDisease(Span("reserpine", sentence=9130, chars=[19,27], words=[5,5]), Span("tremor", sentence=9130, chars=[50,55], words=[9,9])),
#   ChemicalDisease(Span("haloperidol-induced", sentence=6808, chars=[104,122], words=[22,22]), Span("catalepsy", sentence=6808, chars=[124,132], words=[23,23])),
#   ChemicalDisease(Span("cefotetan", sentence=9790, chars=[56,64], words=[7,7]), Span("hemolytic anemia", sentence=9790, chars=[131,146], words=[18,19])),
#   ChemicalDisease(Span("BHA", sentence=6138, chars=[64,66], words=[11,11]), Span("forestomach carcinogenesis", sentence=6138, chars=[68,93], words=[12,13])),
#   ChemicalDisease(Span("cefotetan-induced", sentence=9791, chars=[38,54], words=[9,9]), Span("hemolytic anemias", sentence=9791, chars=[56,72], words=[10,11])),
#   ChemicalDisease(Span("carbamazepine", sentence=6790, chars=[72,84], words=[11,11]), Span("atrioventricular block", sentence=6790, chars=[37,58], words=[6,7])),
#   ChemicalDisease(Span("morphine", sentence=9956, chars=[66,73], words=[12,12]), Span("catalepsy", sentence=9956, chars=[45,53], words=[9,9])),
#   ChemicalDisease(Span("morphine", sentence=9959, chars=[140,147], words=[20,20]), Span("catalepsy", sentence=9959, chars=[102,110], words=[14,14])),
#   ChemicalDisease(Span("epsilon-aminocaproic acid", sentence=6971, chars=[46,70], words=[9,10]), Span("necrotizing myopathy", sentence=6971, chars=[10,29], words=[3,4])),
#   ChemicalDisease(Span("EACA)", sentence=6971, chars=[73,77], words=[12,13]), Span("necrotizing myopathy", sentence=6971, chars=[10,29], words=[3,4]))},
#  {ChemicalDisease(Span("levodopa-induced", sentence=9663, chars=[88,103], words=[12,12]), Span("idiopathic Parkinson's disease", sentence=9663, chars=[157,186], words=[21,24])),
#   ChemicalDisease(Span("nitric oxide-induced", sentence=8572, chars=[46,65], words=[5,6]), Span("tension-type headache", sentence=8572, chars=[101,121], words=[12,13])),
#   ChemicalDisease(Span("carbamazepine", sentence=6792, chars=[75,87], words=[12,12]), Span("overdose", sentence=6792, chars=[89,96], words=[13,13])),
#   ChemicalDisease(Span("chloroquine-induced", sentence=7391, chars=[15,33], words=[3,3]), Span("myopathy", sentence=7391, chars=[35,42], words=[4,4])),
#   ChemicalDisease(Span("Estrogens", sentence=7158, chars=[0,8], words=[0,0]), Span("cancers", sentence=7158, chars=[77,83], words=[13,13])),
#   ChemicalDisease(Span("ARB)", sentence=7315, chars=[89,92], words=[13,14]), Span("intestinal angioedema", sentence=7315, chars=[94,114], words=[15,16])),
#   ChemicalDisease(Span("estrogen", sentence=7168, chars=[147,154], words=[27,27]), Span("tumor", sentence=7168, chars=[164,168], words=[29,29])),
#   ChemicalDisease(Span("Amphetamine-induced", sentence=7079, chars=[0,18], words=[0,0]), Span("locomotor hyperactivity", sentence=7079, chars=[20,42], words=[1,2])),
#   ChemicalDisease(Span("Amiodarone", sentence=10439, chars=[0,9], words=[0,0]), Span("pulmonary toxicity", sentence=10439, chars=[11,28], words=[1,2])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8422, chars=[109,121], words=[21,21]), Span("urticaria", sentence=8422, chars=[58,66], words=[11,11])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8422, chars=[109,121], words=[21,21]), Span("urticaria/angioedema", sentence=8422, chars=[123,142], words=[22,22])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8422, chars=[109,121], words=[21,21]), Span("urticaria)", sentence=8422, chars=[189,198], words=[31,32])),
#   ChemicalDisease(Span("steroid-induced", sentence=6399, chars=[14,28], words=[2,2]), Span("IOP rise", sentence=6399, chars=[30,37], words=[3,4])),
#   ChemicalDisease(Span("PB", sentence=8401, chars=[29,30], words=[4,4]), Span("liver damage", sentence=8401, chars=[63,74], words=[10,11])),
#   ChemicalDisease(Span("CB 3717", sentence=9087, chars=[220,226], words=[50,51]), Span("cytotoxicity", sentence=9087, chars=[228,239], words=[52,52])),
#   ChemicalDisease(Span("dipyridamole-induced", sentence=6444, chars=[7,26], words=[1,1]), Span("coronary stenosis", sentence=6444, chars=[72,88], words=[12,13])),
#   ChemicalDisease(Span("NSAIDs", sentence=8423, chars=[147,152], words=[20,20]), Span("urticaria/angioedema", sentence=8423, chars=[116,135], words=[17,17])),
#   ChemicalDisease(Span("milrinone-induced", sentence=9316, chars=[32,48], words=[5,5]), Span("heart failure", sentence=9316, chars=[72,84], words=[9,10])),
#   ChemicalDisease(Span("Gentamicin", sentence=9615, chars=[0,9], words=[0,0]), Span("nephropathy", sentence=9615, chars=[11,21], words=[1,1])),
#   ChemicalDisease(Span("puromycin aminonucleoside-induced", sentence=7059, chars=[43,75], words=[5,6]), Span("hematological abnormalities", sentence=7059, chars=[77,103], words=[7,8])),
#   ChemicalDisease(Span("Puromycin aminonucleoside-induced", sentence=7060, chars=[0,32], words=[0,1]), Span("renal dysfunction", sentence=7060, chars=[34,50], words=[2,3])),
#   ChemicalDisease(Span("Puromycin aminonucleoside-induced", sentence=7060, chars=[0,32], words=[0,1]), Span("hyperlipidemia", sentence=7060, chars=[56,69], words=[5,5])),
#   ChemicalDisease(Span("NO)", sentence=8573, chars=[40,42], words=[8,9]), Span("primary headaches", sentence=8573, chars=[64,80], words=[13,14])),
#   ChemicalDisease(Span("Warfarin-induced", sentence=7090, chars=[0,15], words=[0,0]), Span("leukocytoclastic vasculitis", sentence=7090, chars=[17,43], words=[1,2])),
#   ChemicalDisease(Span("puromycin aminonucleoside-induced", sentence=7064, chars=[84,116], words=[13,14]), Span("nephrotic syndrome", sentence=7064, chars=[118,135], words=[15,16])),
#   ChemicalDisease(Span("lindane", sentence=8854, chars=[92,98], words=[15,15]), Span("neurotoxicity", sentence=8854, chars=[108,120], words=[17,17])),
#   ChemicalDisease(Span("puromycin aminonucleoside-induced", sentence=7055, chars=[101,133], words=[17,18]), Span("nephrotic syndrome", sentence=7055, chars=[186,203], words=[28,29])),
#   ChemicalDisease(Span("nicotine-induced", sentence=7202, chars=[23,38], words=[3,3]), Span("locomotor hyperactivity", sentence=7202, chars=[40,62], words=[4,5])),
#   ChemicalDisease(Span("dobutamine", sentence=8582, chars=[56,65], words=[8,8]), Span("Myocardial ischemia", sentence=8582, chars=[0,18], words=[0,1])),
#   ChemicalDisease(Span("amiodarone-induced", sentence=10442, chars=[42,59], words=[6,6]), Span("pulmonary toxicity", sentence=10442, chars=[61,78], words=[7,8])),
#   ChemicalDisease(Span("acetylcholine", sentence=8588, chars=[57,69], words=[8,8]), Span("spasm", sentence=8588, chars=[9,13], words=[1,1])),
#   ChemicalDisease(Span("levodopa-induced", sentence=9665, chars=[26,41], words=[5,5]), Span("dystonia", sentence=9665, chars=[83,90], words=[13,13])),
#   ChemicalDisease(Span("cocaine-induced", sentence=7337, chars=[201,215], words=[30,30]), Span("psychiatric", sentence=7337, chars=[135,145], words=[20,20])),
#   ChemicalDisease(Span("anthracycline-induced", sentence=9939, chars=[61,81], words=[9,9]), Span("cardiotoxicity", sentence=9939, chars=[83,96], words=[10,10])),
#   ChemicalDisease(Span("steroids", sentence=9155, chars=[143,150], words=[27,27]), Span("atrophy", sentence=9155, chars=[183,189], words=[32,32])),
#   ChemicalDisease(Span("steroid", sentence=9155, chars=[279,285], words=[48,48]), Span("muscle necrosis", sentence=9155, chars=[294,308], words=[50,51])),
#   ChemicalDisease(Span("steroid", sentence=9155, chars=[279,285], words=[48,48]), Span("atrophy", sentence=9155, chars=[324,330], words=[58,58])),
#   ChemicalDisease(Span("estrogen", sentence=7159, chars=[64,71], words=[9,9]), Span("carcinogenesis", sentence=7159, chars=[73,86], words=[10,10])),
#   ChemicalDisease(Span("cephalosporins", sentence=9790, chars=[29,42], words=[4,4]), Span("hemolytic anemia", sentence=9790, chars=[131,146], words=[18,19])),
#   ChemicalDisease(Span("warfarin", sentence=7093, chars=[56,63], words=[10,10]), Span("LV", sentence=7093, chars=[37,38], words=[6,6])),
#   ChemicalDisease(Span("Carbamazepine-induced", sentence=6788, chars=[0,20], words=[0,0]), Span("cardiac dysfunction", sentence=6788, chars=[22,40], words=[1,2])),
#   ChemicalDisease(Span("carbamazepine", sentence=6790, chars=[72,84], words=[11,11]), Span("sinus bradycardia", sentence=6790, chars=[15,31], words=[3,4])),
#   ChemicalDisease(Span("estrogen-induced", sentence=7157, chars=[97,112], words=[14,14]), Span("tumor", sentence=7157, chars=[166,170], words=[21,21])),
#   ChemicalDisease(Span("estrogen-induced", sentence=7157, chars=[97,112], words=[14,14]), Span("pituitary tumors", sentence=7157, chars=[118,133], words=[16,17])),
#   ChemicalDisease(Span("estrogen-initiated", sentence=7157, chars=[147,164], words=[20,20]), Span("tumor", sentence=7157, chars=[166,170], words=[21,21])),
#   ChemicalDisease(Span("carbamazepine-associated", sentence=6791, chars=[56,79], words=[11,11]), Span("cardiac dysfunction", sentence=6791, chars=[81,99], words=[12,13])),
#   ChemicalDisease(Span("chloroquine-induced", sentence=7382, chars=[80,98], words=[13,13]), Span("myopathy", sentence=7382, chars=[100,107], words=[14,14])),
#   ChemicalDisease(Span("BHA-induced", sentence=6135, chars=[145,155], words=[31,31]), Span("epithelial hyperplasia", sentence=6135, chars=[157,178], words=[32,33])),
#   ChemicalDisease(Span("lithium carbonate", sentence=6098, chars=[34,50], words=[4,5]), Span("toxicity", sentence=6098, chars=[52,59], words=[6,6])),
#   ChemicalDisease(Span("doxorubicin-induced", sentence=6367, chars=[105,123], words=[16,16]), Span("cardiotoxicity", sentence=6367, chars=[62,75], words=[11,11])),
#   ChemicalDisease(Span("doxorubicin-induced", sentence=6367, chars=[105,123], words=[16,16]), Span("cardiotoxicity", sentence=6367, chars=[125,138], words=[17,17]))},
#  {ChemicalDisease(Span("fluocinolone acetonide", sentence=10491, chars=[131,152], words=[22,23]), Span("uveitis", sentence=10491, chars=[106,112], words=[18,18])),
#   ChemicalDisease(Span("FA)", sentence=10491, chars=[155,157], words=[25,26]), Span("uveitis", sentence=10491, chars=[106,112], words=[18,18])),
#   ChemicalDisease(Span("N-terminal pro brain natriuretic peptide", sentence=6659, chars=[27,66], words=[4,8]), Span("cardiovascular toxicity", sentence=6659, chars=[217,239], words=[33,34])),
#   ChemicalDisease(Span("NT-proBNP)", sentence=6659, chars=[69,78], words=[10,11]), Span("cardiovascular toxicity", sentence=6659, chars=[217,239], words=[33,34])),
#   ChemicalDisease(Span("MK-801", sentence=7103, chars=[41,46], words=[8,8]), Span("spastic paraparesis", sentence=7103, chars=[130,148], words=[23,24])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=9907, chars=[56,71], words=[8,8]), Span("MM", sentence=9907, chars=[176,177], words=[27,27])),
#   ChemicalDisease(Span("bortezomib", sentence=9907, chars=[25,34], words=[4,4]), Span("MM", sentence=9907, chars=[176,177], words=[27,27])),
#   ChemicalDisease(Span("dexamethasone", sentence=9907, chars=[92,104], words=[16,16]), Span("MM", sentence=9907, chars=[176,177], words=[27,27])),
#   ChemicalDisease(Span("creatine", sentence=7381, chars=[37,44], words=[5,5]), Span("systemic lupus erythematosus", sentence=7381, chars=[63,90], words=[9,11])),
#   ChemicalDisease(Span("tacrine-loaded", sentence=8291, chars=[29,42], words=[5,5]), Span("epileptic", sentence=8291, chars=[114,122], words=[17,17])),
#   ChemicalDisease(Span("creatine", sentence=10353, chars=[42,49], words=[7,7]), Span("Myopathy", sentence=10353, chars=[0,7], words=[0,0])),
#   ChemicalDisease(Span("N,N'-dibenzhydrylethane-1,2-diamine dihydrochloride", sentence=6807, chars=[15,65], words=[3,12]), Span("PD", sentence=6807, chars=[185,186], words=[34,34])),
#   ChemicalDisease(Span("AMN082)", sentence=6807, chars=[68,74], words=[14,15]), Span("PD", sentence=6807, chars=[185,186], words=[34,34])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=9899, chars=[47,62], words=[8,8]), Span("myeloma", sentence=9899, chars=[166,172], words=[21,21])),
#   ChemicalDisease(Span("bortezomib/dexamethasone", sentence=9899, chars=[84,107], words=[12,12]), Span("myeloma", sentence=9899, chars=[166,172], words=[21,21])),
#   ChemicalDisease(Span("estrogen", sentence=7160, chars=[25,32], words=[5,5]), Span("tumor", sentence=7160, chars=[55,59], words=[10,10])),
#   ChemicalDisease(Span("trihexyphenidyl", sentence=9745, chars=[122,136], words=[19,19]), Span("confusion", sentence=9745, chars=[174,182], words=[25,25])),
#   ChemicalDisease(Span("trihexyphenidyl-induced", sentence=9745, chars=[228,250], words=[32,32]), Span("confusion", sentence=9745, chars=[174,182], words=[25,25])),
#   ChemicalDisease(Span("reserpine", sentence=9133, chars=[24,32], words=[4,4]), Span("parkinsonian-like", sentence=9133, chars=[150,166], words=[24,24])),
#   ChemicalDisease(Span("reserpine", sentence=9133, chars=[24,32], words=[4,4]), Span("tardive dsykinesia", sentence=9133, chars=[172,189], words=[26,27])),
#   ChemicalDisease(Span("sulindac", sentence=9732, chars=[114,121], words=[15,15]), Span("colorectal adenomas", sentence=9732, chars=[150,168], words=[20,21])),
#   ChemicalDisease(Span("amiodarone", sentence=10441, chars=[26,35], words=[4,4]), Span("pulmonary toxicity", sentence=10441, chars=[4,21], words=[1,2])),
#   ChemicalDisease(Span("Myocet", sentence=9972, chars=[12,17], words=[2,2]), Span("cardiotoxicity", sentence=9972, chars=[91,104], words=[12,12])),
#   ChemicalDisease(Span("Myocet", sentence=9972, chars=[12,17], words=[2,2]), Span("MBC", sentence=9972, chars=[247,249], words=[33,33])),
#   ChemicalDisease(Span("doxorubicin", sentence=9972, chars=[53,63], words=[8,8]), Span("cardiotoxicity", sentence=9972, chars=[91,104], words=[12,12])),
#   ChemicalDisease(Span("doxorubicin", sentence=9972, chars=[53,63], words=[8,8]), Span("MBC", sentence=9972, chars=[247,249], words=[33,33])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=9972, chars=[204,219], words=[28,28]), Span("cardiotoxicity", sentence=9972, chars=[91,104], words=[12,12])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=9972, chars=[204,219], words=[28,28]), Span("MBC", sentence=9972, chars=[247,249], words=[33,33])),
#   ChemicalDisease(Span("heroin", sentence=9459, chars=[70,75], words=[10,10]), Span("QT prolongation", sentence=9459, chars=[12,26], words=[2,3])),
#   ChemicalDisease(Span("heroin", sentence=9459, chars=[70,75], words=[10,10]), Span("Syncope", sentence=9459, chars=[0,6], words=[0,0])),
#   ChemicalDisease(Span("deoxycholic acid", sentence=7241, chars=[58,73], words=[6,7]), Span("cholestasis", sentence=7241, chars=[104,114], words=[11,11])),
#   ChemicalDisease(Span("cefotetan", sentence=9002, chars=[71,79], words=[10,10]), Span("anemia", sentence=9002, chars=[36,41], words=[6,6])),
#   ChemicalDisease(Span("cisapride", sentence=7827, chars=[124,132], words=[14,14]), Span("diarrhoea-predominant", sentence=7827, chars=[12,32], words=[3,3])),
#   ChemicalDisease(Span("sulindac", sentence=9733, chars=[144,151], words=[22,22]), Span("adenomatous polyps", sentence=9733, chars=[54,71], words=[9,10])),
#   ChemicalDisease(Span("DX", sentence=7996, chars=[68,69], words=[10,10]), Span("glomerulonephritis", sentence=7996, chars=[33,50], words=[5,5])),
#   ChemicalDisease(Span("retinyl acetate", sentence=6132, chars=[34,48], words=[5,6]), Span("forestomach tumorigenesis", sentence=6132, chars=[101,125], words=[19,20])),
#   ChemicalDisease(Span("RA)", sentence=6132, chars=[51,53], words=[8,9]), Span("forestomach tumorigenesis", sentence=6132, chars=[101,125], words=[19,20])),
#   ChemicalDisease(Span("D-penicillamine", sentence=9369, chars=[0,14], words=[0,0]), Span("localized scleroderma", sentence=9369, chars=[36,56], words=[5,6])),
#   ChemicalDisease(Span("RA", sentence=6136, chars=[64,65], words=[17,17]), Span("Tumors", sentence=6136, chars=[0,5], words=[0,0])),
#   ChemicalDisease(Span("RA", sentence=6136, chars=[64,65], words=[17,17]), Span("papillomas", sentence=6136, chars=[12,21], words=[3,3])),
#   ChemicalDisease(Span("RA", sentence=6136, chars=[99,100], words=[29,29]), Span("Tumors", sentence=6136, chars=[0,5], words=[0,0])),
#   ChemicalDisease(Span("RA", sentence=6136, chars=[99,100], words=[29,29]), Span("papillomas", sentence=6136, chars=[12,21], words=[3,3])),
#   ChemicalDisease(Span("5-HT", sentence=9766, chars=[83,86], words=[16,16]), Span("aggressive behavior", sentence=9766, chars=[123,141], words=[23,24])),
#   ChemicalDisease(Span("morphine", sentence=7098, chars=[132,139], words=[17,17]), Span("spinal cord ischemia", sentence=7098, chars=[174,193], words=[23,25])),
#   ChemicalDisease(Span("nitroprusside", sentence=10614, chars=[311,323], words=[44,44]), Span("ischemia", sentence=10614, chars=[234,241], words=[32,32])),
#   ChemicalDisease(Span("nitroprusside", sentence=10614, chars=[311,323], words=[44,44]), Span("ischemia", sentence=10614, chars=[384,391], words=[54,54])),
#   ChemicalDisease(Span("nitroprusside", sentence=10614, chars=[311,323], words=[44,44]), Span("hypotensive", sentence=10614, chars=[294,304], words=[42,42])),
#   ChemicalDisease(Span("malondialdehyde", sentence=10614, chars=[17,31], words=[2,2]), Span("ischemia", sentence=10614, chars=[234,241], words=[32,32])),
#   ChemicalDisease(Span("malondialdehyde", sentence=10614, chars=[17,31], words=[2,2]), Span("ischemia", sentence=10614, chars=[384,391], words=[54,54])),
#   ChemicalDisease(Span("malondialdehyde", sentence=10614, chars=[17,31], words=[2,2]), Span("hypotensive", sentence=10614, chars=[294,304], words=[42,42])),
#   ChemicalDisease(Span("malondialdehyde", sentence=10614, chars=[424,438], words=[61,61]), Span("ischemia", sentence=10614, chars=[234,241], words=[32,32])),
#   ChemicalDisease(Span("malondialdehyde", sentence=10614, chars=[424,438], words=[61,61]), Span("ischemia", sentence=10614, chars=[384,391], words=[54,54])),
#   ChemicalDisease(Span("malondialdehyde", sentence=10614, chars=[424,438], words=[61,61]), Span("hypotensive", sentence=10614, chars=[294,304], words=[42,42])),
#   ChemicalDisease(Span("acetylsalicylate", sentence=10614, chars=[184,199], words=[28,28]), Span("ischemia", sentence=10614, chars=[234,241], words=[32,32])),
#   ChemicalDisease(Span("acetylsalicylate", sentence=10614, chars=[184,199], words=[28,28]), Span("ischemia", sentence=10614, chars=[384,391], words=[54,54])),
#   ChemicalDisease(Span("acetylsalicylate", sentence=10614, chars=[184,199], words=[28,28]), Span("hypotensive", sentence=10614, chars=[294,304], words=[42,42])),
#   ChemicalDisease(Span("phenytoin", sentence=10158, chars=[3,11], words=[1,1]), Span("hypothermic", sentence=10158, chars=[38,48], words=[6,6])),
#   ChemicalDisease(Span("SM-5887", sentence=6362, chars=[238,244], words=[33,33]), Span("cardiomyopathy", sentence=6362, chars=[165,178], words=[23,23])),
#   ChemicalDisease(Span("dobutamine", sentence=10069, chars=[145,154], words=[20,20]), Span("biventricular failure", sentence=10069, chars=[93,113], words=[14,15])),
#   ChemicalDisease(Span("dobutamine", sentence=10069, chars=[145,154], words=[20,20]), Span("hypertrophic cardiomyopathy", sentence=10069, chars=[46,72], words=[8,9])),
#   ChemicalDisease(Span("quetiapine", sentence=6595, chars=[180,189], words=[41,41]), Span("extrapyramidal syndrome", sentence=6595, chars=[131,153], words=[31,32])),
#   ChemicalDisease(Span("quetiapine", sentence=6595, chars=[180,189], words=[41,41]), Span("tremor", sentence=6595, chars=[99,104], words=[21,21])),
#   ChemicalDisease(Span("quetiapine", sentence=6595, chars=[180,189], words=[41,41]), Span("akathisia", sentence=6595, chars=[68,76], words=[12,12])),
#   ChemicalDisease(Span("metoprolol", sentence=9519, chars=[22,31], words=[3,3]), Span("myocardial ischemia", sentence=9519, chars=[95,113], words=[11,12])),
#   ChemicalDisease(Span("metoprolol", sentence=9519, chars=[48,57], words=[6,6]), Span("myocardial ischemia", sentence=9519, chars=[95,113], words=[11,12])),
#   ChemicalDisease(Span("tacrine-lithium", sentence=8294, chars=[122,136], words=[18,18]), Span("epilepsy", sentence=8294, chars=[147,154], words=[21,21])),
#   ChemicalDisease(Span("Estrogens", sentence=7158, chars=[0,8], words=[0,0]), Span("tumor", sentence=7158, chars=[97,101], words=[17,17])),
#   ChemicalDisease(Span("D-penicillamine", sentence=9372, chars=[95,109], words=[15,15]), Span("localized scleroderma", sentence=9372, chars=[51,71], words=[9,10])),
#   ChemicalDisease(Span("Tiapride", sentence=9662, chars=[0,7], words=[0,0]), Span("involuntary movements", sentence=9662, chars=[29,49], words=[3,4])),
#   ChemicalDisease(Span("Li/DVP", sentence=6593, chars=[117,122], words=[26,26]), Span("akathisia", sentence=6593, chars=[17,25], words=[3,3])),
#   ChemicalDisease(Span("Li/DVP", sentence=6593, chars=[141,146], words=[34,34]), Span("akathisia", sentence=6593, chars=[17,25], words=[3,3])),
#   ChemicalDisease(Span("quetiapine", sentence=6593, chars=[52,61], words=[9,9]), Span("akathisia", sentence=6593, chars=[17,25], words=[3,3])),
#   ChemicalDisease(Span("QTP", sentence=6593, chars=[111,113], words=[24,24]), Span("akathisia", sentence=6593, chars=[17,25], words=[3,3])),
#   ChemicalDisease(Span("mesna", sentence=6169, chars=[122,126], words=[19,19]), Span("hemorrhagic cystitis", sentence=6169, chars=[202,221], words=[30,31])),
#   ChemicalDisease(Span("methadone", sentence=9461, chars=[106,114], words=[21,21]), Span("torsade de pointes", sentence=9461, chars=[60,77], words=[11,13])),
#   ChemicalDisease(Span("methadone", sentence=9461, chars=[106,114], words=[21,21]), Span("TdP)", sentence=9461, chars=[80,83], words=[15,16])),
#   ChemicalDisease(Span("oral contraceptives", sentence=6186, chars=[104,122], words=[17,18]), Span("hepatic adenoma", sentence=6186, chars=[13,27], words=[3,4])),
#   ChemicalDisease(Span("mesna", sentence=6171, chars=[59,63], words=[10,10]), Span("hemorrhagic cystitis", sentence=6171, chars=[137,156], words=[19,20])),
#   ChemicalDisease(Span("angiotensin-converting", sentence=7315, chars=[19,40], words=[3,3]), Span("intestinal angioedema", sentence=7315, chars=[94,114], words=[15,16])),
#   ChemicalDisease(Span("angiotensin", sentence=7315, chars=[59,69], words=[9,9]), Span("intestinal angioedema", sentence=7315, chars=[94,114], words=[15,16])),
#   ChemicalDisease(Span("cisapride", sentence=7823, chars=[11,19], words=[2,2]), Span("irritable bowel syndrome", sentence=7823, chars=[91,114], words=[13,15])),
#   ChemicalDisease(Span("Tiapride", sentence=9663, chars=[0,7], words=[0,0]), Span("idiopathic Parkinson's disease", sentence=9663, chars=[157,186], words=[21,24])),
#   ChemicalDisease(Span("Tiapride", sentence=9663, chars=[0,7], words=[0,0]), Span("involuntary movements", sentence=9663, chars=[115,135], words=[15,16])),
#   ChemicalDisease(Span("metoclopramide", sentence=9663, chars=[64,77], words=[9,9]), Span("idiopathic Parkinson's disease", sentence=9663, chars=[157,186], words=[21,24])),
#   ChemicalDisease(Span("metoclopramide", sentence=9663, chars=[64,77], words=[9,9]), Span("involuntary movements", sentence=9663, chars=[115,135], words=[15,16])),
#   ChemicalDisease(Span("benzamide", sentence=9663, chars=[24,32], words=[4,4]), Span("idiopathic Parkinson's disease", sentence=9663, chars=[157,186], words=[21,24])),
#   ChemicalDisease(Span("benzamide", sentence=9663, chars=[24,32], words=[4,4]), Span("involuntary movements", sentence=9663, chars=[115,135], words=[15,16])),
#   ChemicalDisease(Span("Calcitriol", sentence=8151, chars=[12,21], words=[2,2]), Span("bone disease", sentence=8151, chars=[237,248], words=[37,38])),
#   ChemicalDisease(Span("Calcitriol", sentence=8151, chars=[12,21], words=[2,2]), Span("renal failure", sentence=8151, chars=[101,113], words=[16,17])),
#   ChemicalDisease(Span("benzodiazepine-GABA-chloride", sentence=9359, chars=[49,76], words=[8,8]), Span("bradycardia", sentence=9359, chars=[164,174], words=[20,20])),
#   ChemicalDisease(Span("lithium", sentence=10319, chars=[93,99], words=[18,18]), Span("bipolar disorder", sentence=10319, chars=[66,81], words=[15,16])),
#   ChemicalDisease(Span("prednisone", sentence=8266, chars=[33,42], words=[5,5]), Span("lethargy", sentence=8266, chars=[65,72], words=[10,10])),
#   ChemicalDisease(Span("prednisone", sentence=8266, chars=[33,42], words=[5,5]), Span("somnolence", sentence=8266, chars=[86,95], words=[13,13])),
#   ChemicalDisease(Span("prednisone", sentence=8266, chars=[33,42], words=[5,5]), Span("polyuria", sentence=8266, chars=[126,133], words=[20,20])),
#   ChemicalDisease(Span("prednisone", sentence=8266, chars=[33,42], words=[5,5]), Span("polyphagia", sentence=8266, chars=[110,119], words=[17,17])),
#   ChemicalDisease(Span("prednisone", sentence=8266, chars=[33,42], words=[5,5]), Span("polydipsia", sentence=8266, chars=[98,107], words=[15,15])),
#   ChemicalDisease(Span("tropicamide", sentence=10561, chars=[68,78], words=[11,11]), Span("impairment in word recall", sentence=10561, chars=[117,141], words=[16,19])),
#   ChemicalDisease(Span("pilocarpine", sentence=10561, chars=[84,94], words=[13,13]), Span("impairment in word recall", sentence=10561, chars=[117,141], words=[16,19])),
#   ChemicalDisease(Span("steroid", sentence=9153, chars=[106,112], words=[18,18]), Span("necrosis", sentence=9153, chars=[252,259], words=[40,40])),
#   ChemicalDisease(Span("steroid", sentence=9153, chars=[106,112], words=[18,18]), Span("diaphragmatic type IIa atrophy", sentence=9153, chars=[130,159], words=[22,25])),
#   ChemicalDisease(Span("steroid", sentence=9153, chars=[106,112], words=[18,18]), Span("atrophy", sentence=9153, chars=[91,97], words=[15,15])),
#   ChemicalDisease(Span("T", sentence=9153, chars=[166,166], words=[27,27]), Span("necrosis", sentence=9153, chars=[252,259], words=[40,40])),
#   ChemicalDisease(Span("T", sentence=9153, chars=[166,166], words=[27,27]), Span("diaphragmatic type IIa atrophy", sentence=9153, chars=[130,159], words=[22,25])),
#   ChemicalDisease(Span("T", sentence=9153, chars=[166,166], words=[27,27]), Span("atrophy", sentence=9153, chars=[91,97], words=[15,15])),
#   ChemicalDisease(Span("calcium", sentence=7348, chars=[72,78], words=[12,12]), Span("overdose", sentence=7348, chars=[108,115], words=[17,17])),
#   ChemicalDisease(Span("calcium", sentence=7348, chars=[72,78], words=[12,12]), Span("asystole", sentence=7348, chars=[149,156], words=[24,24])),
#   ChemicalDisease(Span("steroids", sentence=7386, chars=[57,64], words=[10,10]), Span("Myositis", sentence=7386, chars=[0,7], words=[0,0])),
#   ChemicalDisease(Span("paroxetine", sentence=8347, chars=[44,53], words=[7,7]), Span("chronic pain", sentence=8347, chars=[115,126], words=[16,17])),
#   ChemicalDisease(Span("dosulepine hydrochloride", sentence=8347, chars=[59,82], words=[9,10]), Span("chronic pain", sentence=8347, chars=[115,126], words=[16,17])),
#   ChemicalDisease(Span("lithium", sentence=10328, chars=[99,105], words=[14,14]), Span("thyroid illness", sentence=10328, chars=[22,36], words=[3,4])),
#   ChemicalDisease(Span("lithium", sentence=10328, chars=[99,105], words=[14,14]), Span("hypercalcemia", sentence=10328, chars=[78,90], words=[12,12])),
#   ChemicalDisease(Span("amlodipine/benazapril", sentence=7306, chars=[139,159], words=[24,24]), Span("hypertension", sentence=7306, chars=[84,95], words=[14,14])),
#   ChemicalDisease(Span("3-methylcholanthrene", sentence=8860, chars=[64,83], words=[9,9]), Span("convulsions", sentence=8860, chars=[193,203], words=[31,31])),
#   ChemicalDisease(Span("3-methylcholanthrene", sentence=8860, chars=[64,83], words=[9,9]), Span("convulsions", sentence=8860, chars=[384,394], words=[63,63])),
#   ChemicalDisease(Span("MC)", sentence=8860, chars=[86,88], words=[11,12]), Span("convulsions", sentence=8860, chars=[193,203], words=[31,31])),
#   ChemicalDisease(Span("MC)", sentence=8860, chars=[86,88], words=[11,12]), Span("convulsions", sentence=8860, chars=[384,394], words=[63,63])),
#   ChemicalDisease(Span("phenobarbital", sentence=8860, chars=[224,236], words=[35,35]), Span("convulsions", sentence=8860, chars=[193,203], words=[31,31])),
#   ChemicalDisease(Span("phenobarbital", sentence=8860, chars=[224,236], words=[35,35]), Span("convulsions", sentence=8860, chars=[384,394], words=[63,63])),
#   ChemicalDisease(Span("PB)", sentence=8860, chars=[239,241], words=[37,38]), Span("convulsions", sentence=8860, chars=[193,203], words=[31,31])),
#   ChemicalDisease(Span("PB)", sentence=8860, chars=[239,241], words=[37,38]), Span("convulsions", sentence=8860, chars=[384,394], words=[63,63])),
#   ChemicalDisease(Span("ethanol", sentence=8860, chars=[274,280], words=[46,46]), Span("convulsions", sentence=8860, chars=[193,203], words=[31,31])),
#   ChemicalDisease(Span("ethanol", sentence=8860, chars=[274,280], words=[46,46]), Span("convulsions", sentence=8860, chars=[384,394], words=[63,63])),
#   ChemicalDisease(Span("lindane", sentence=8861, chars=[48,54], words=[7,7]), Span("toxicity", sentence=8861, chars=[294,301], words=[44,44])),
#   ChemicalDisease(Span("lindane", sentence=8861, chars=[150,156], words=[22,22]), Span("toxicity", sentence=8861, chars=[294,301], words=[44,44])),
#   ChemicalDisease(Span("lindane", sentence=8861, chars=[174,180], words=[25,25]), Span("toxicity", sentence=8861, chars=[294,301], words=[44,44])),
#   ChemicalDisease(Span("cobalt chloride", sentence=8861, chars=[71,85], words=[11,12]), Span("convulsions", sentence=8861, chars=[100,110], words=[15,15])),
#   ChemicalDisease(Span("cobalt chloride", sentence=8861, chars=[71,85], words=[11,12]), Span("toxicity", sentence=8861, chars=[294,301], words=[44,44])),
#   ChemicalDisease(Span("PB", sentence=8861, chars=[218,219], words=[33,33]), Span("convulsions", sentence=8861, chars=[100,110], words=[15,15])),
#   ChemicalDisease(Span("PB", sentence=8861, chars=[218,219], words=[33,33]), Span("toxicity", sentence=8861, chars=[294,301], words=[44,44])),
#   ChemicalDisease(Span("ethanol", sentence=8861, chars=[224,230], words=[35,35]), Span("convulsions", sentence=8861, chars=[100,110], words=[15,15])),
#   ChemicalDisease(Span("ethanol", sentence=8861, chars=[224,230], words=[35,35]), Span("toxicity", sentence=8861, chars=[294,301], words=[44,44])),
#   ChemicalDisease(Span("phenytoin", sentence=10163, chars=[34,42], words=[5,5]), Span("hypothermia", sentence=10163, chars=[48,58], words=[7,7])),
#   ChemicalDisease(Span("ACEI)", sentence=7313, chars=[41,45], words=[4,5]), Span("anti-hypertensive", sentence=7313, chars=[85,101], words=[13,13])),
#   ChemicalDisease(Span("ACEI)", sentence=7313, chars=[41,45], words=[4,5]), Span("angioedema", sentence=7313, chars=[55,64], words=[8,8])),
#   ChemicalDisease(Span("SM-5887", sentence=6363, chars=[58,64], words=[8,8]), Span("cardiomyopathy", sentence=6363, chars=[77,90], words=[11,11])),
#   ChemicalDisease(Span("SM-5887", sentence=6363, chars=[58,64], words=[8,8]), Span("cardiotoxic", sentence=6363, chars=[36,46], words=[5,5])),
#   ChemicalDisease(Span("Reserpine", sentence=9126, chars=[0,8], words=[0,0]), Span("Parkinson's disease", sentence=9126, chars=[76,94], words=[12,14])),
#   ChemicalDisease(Span("METH-induced", sentence=6259, chars=[53,64], words=[8,8]), Span("hyperactivity", sentence=6259, chars=[66,78], words=[9,9])),
#   ChemicalDisease(Span("chloroquine", sentence=7384, chars=[24,34], words=[3,3]), Span("arthralgia", sentence=7384, chars=[64,73], words=[11,11])),
#   ChemicalDisease(Span("CQ)", sentence=7384, chars=[37,39], words=[5,6]), Span("arthralgia", sentence=7384, chars=[64,73], words=[11,11])),
#   ChemicalDisease(Span("nitric oxide", sentence=9512, chars=[58,69], words=[9,10]), Span("convulsions", sentence=9512, chars=[166,176], words=[27,27])),
#   ChemicalDisease(Span("NO)", sentence=9512, chars=[72,74], words=[12,13]), Span("convulsions", sentence=9512, chars=[166,176], words=[27,27])),
#   ChemicalDisease(Span("NO", sentence=9512, chars=[113,114], words=[20,20]), Span("convulsions", sentence=9512, chars=[166,176], words=[27,27])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=9900, chars=[67,82], words=[11,11]), Span("multiple myeloma", sentence=9900, chars=[231,246], words=[31,32])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=9900, chars=[67,82], words=[11,11]), Span("MM)", sentence=9900, chars=[249,251], words=[34,35])),
#   ChemicalDisease(Span("bortezomib", sentence=9900, chars=[104,113], words=[15,15]), Span("multiple myeloma", sentence=9900, chars=[231,246], words=[31,32])),
#   ChemicalDisease(Span("bortezomib", sentence=9900, chars=[104,113], words=[15,15]), Span("MM)", sentence=9900, chars=[249,251], words=[34,35])),
#   ChemicalDisease(Span("dexamethasone", sentence=9900, chars=[119,131], words=[17,17]), Span("multiple myeloma", sentence=9900, chars=[231,246], words=[31,32])),
#   ChemicalDisease(Span("dexamethasone", sentence=9900, chars=[119,131], words=[17,17]), Span("MM)", sentence=9900, chars=[249,251], words=[34,35])),
#   ChemicalDisease(Span("rifampicin", sentence=9010, chars=[92,101], words=[12,12]), Span("renal failure", sentence=9010, chars=[37,49], words=[5,6])),
#   ChemicalDisease(Span("oral contraceptives", sentence=6185, chars=[78,96], words=[13,14]), Span("Hepatic adenomas", sentence=6185, chars=[0,15], words=[0,1])),
#   ChemicalDisease(Span("sulphasalazine", sentence=10155, chars=[22,35], words=[3,3]), Span("chest pain", sentence=10155, chars=[92,101], words=[14,15])),
#   ChemicalDisease(Span("steroid", sentence=10155, chars=[182,188], words=[30,30]), Span("fever", sentence=10155, chars=[75,79], words=[9,9])),
#   ChemicalDisease(Span("steroid", sentence=10155, chars=[182,188], words=[30,30]), Span("chest pain", sentence=10155, chars=[92,101], words=[14,15])),
#   ChemicalDisease(Span("steroid", sentence=10155, chars=[182,188], words=[30,30]), Span("pleural effusions", sentence=10155, chars=[150,166], words=[25,26])),
#   ChemicalDisease(Span("steroid", sentence=10155, chars=[182,188], words=[30,30]), Span("pleural effusion", sentence=10155, chars=[296,311], words=[50,51])),
#   ChemicalDisease(Span("lithium", sentence=10323, chars=[137,143], words=[20,20]), Span("thyroid illness", sentence=10323, chars=[55,69], words=[7,8])),
#   ChemicalDisease(Span("lithium", sentence=10323, chars=[228,234], words=[36,36]), Span("thyroid illness", sentence=10323, chars=[55,69], words=[7,8])),
#   ChemicalDisease(Span("PTU-associated", sentence=7939, chars=[0,13], words=[0,0]), Span("Turner Syndrome", sentence=7939, chars=[41,55], words=[6,7])),
#   ChemicalDisease(Span("NSAID-induced", sentence=8424, chars=[156,168], words=[29,29]), Span("urticaria", sentence=8424, chars=[114,122], words=[19,19])),
#   ChemicalDisease(Span("aspirin", sentence=7342, chars=[87,93], words=[18,18]), Span("overdose", sentence=7342, chars=[31,38], words=[8,8])),
#   ChemicalDisease(Span("nitrate", sentence=7342, chars=[107,113], words=[21,21]), Span("overdose", sentence=7342, chars=[31,38], words=[8,8])),
#   ChemicalDisease(Span("alcohol", sentence=7342, chars=[120,126], words=[24,24]), Span("overdose", sentence=7342, chars=[31,38], words=[8,8])),
#   ChemicalDisease(Span("paracetamol", sentence=7342, chars=[74,84], words=[16,16]), Span("overdose", sentence=7342, chars=[31,38], words=[8,8])),
#   ChemicalDisease(Span("isosorbide", sentence=7342, chars=[96,105], words=[20,20]), Span("overdose", sentence=7342, chars=[31,38], words=[8,8])),
#   ChemicalDisease(Span("doxorubicin", sentence=6365, chars=[66,76], words=[9,9]), Span("cardiotoxic", sentence=6365, chars=[14,24], words=[2,2])),
#   ChemicalDisease(Span("thalidomide", sentence=8543, chars=[20,30], words=[5,5]), Span("renal cell carcinoma", sentence=8543, chars=[55,74], words=[9,11])),
#   ChemicalDisease(Span("SM-5887", sentence=6366, chars=[21,27], words=[5,5]), Span("cardiomyopathy", sentence=6366, chars=[69,82], words=[13,13])),
#   ChemicalDisease(Span("etoposide", sentence=8002, chars=[84,92], words=[11,11]), Span("coronary heart disease", sentence=8002, chars=[129,150], words=[21,23])),
#   ChemicalDisease(Span("imipenem", sentence=10408, chars=[22,29], words=[3,3]), Span("Seizure", sentence=10408, chars=[0,6], words=[0,0])),
#   ChemicalDisease(Span("timolol", sentence=8731, chars=[35,41], words=[6,6]), Span("hypokalemia", sentence=8731, chars=[66,76], words=[12,12])),
#   ChemicalDisease(Span("heparin", sentence=9872, chars=[53,59], words=[8,8]), Span("pelvic thrombophlebitis", sentence=9872, chars=[83,105], words=[12,13])),
#   ChemicalDisease(Span("gentamicin", sentence=9617, chars=[10,19], words=[2,2]), Span("anuria", sentence=9617, chars=[65,70], words=[9,9])),
#   ChemicalDisease(Span("MK-801", sentence=7106, chars=[3,8], words=[1,1]), Span("spastic paraparesis", sentence=7106, chars=[100,118], words=[11,12])),
#   ChemicalDisease(Span("doxorubicin", sentence=6363, chars=[131,141], words=[20,20]), Span("cardiotoxic", sentence=6363, chars=[36,46], words=[5,5])),
#   ChemicalDisease(Span("estrogens", sentence=10627, chars=[113,121], words=[16,16]), Span("ovarian failure", sentence=10627, chars=[8,22], words=[2,3])),
# ...
#   ChemicalDisease(Span("fluvoxamine", sentence=10128, chars=[72,82], words=[10,10]), Span("hyperactivity", sentence=10128, chars=[4,16], words=[1,1])),
#   ChemicalDisease(Span("reserpine-treated", sentence=9128, chars=[71,87], words=[11,11]), Span("tremor", sentence=9128, chars=[61,66], words=[9,9])),
#   ChemicalDisease(Span("dexmedetomidine", sentence=6252, chars=[9,23], words=[1,1]), Span("bradycardia", sentence=6252, chars=[73,83], words=[11,11])),
#   ChemicalDisease(Span("butylated hydroxyanisole", sentence=6131, chars=[103,126], words=[14,15]), Span("forestomach carcinogenesis", sentence=6131, chars=[45,70], words=[6,7])),
#   ChemicalDisease(Span("T", sentence=9154, chars=[57,57], words=[16,16]), Span("muscle atrophy", sentence=9154, chars=[81,94], words=[24,25])),
#   ChemicalDisease(Span("T-treated", sentence=9154, chars=[151,159], words=[35,35]), Span("muscle atrophy", sentence=9154, chars=[81,94], words=[24,25])),
#   ChemicalDisease(Span("valsartan", sentence=10114, chars=[147,155], words=[29,29]), Span("edema", sentence=10114, chars=[40,44], words=[5,5])),
#   ChemicalDisease(Span("valsartan", sentence=10114, chars=[191,199], words=[41,41]), Span("edema", sentence=10114, chars=[40,44], words=[5,5])),
#   ChemicalDisease(Span("amlodipine", sentence=10114, chars=[73,82], words=[11,11]), Span("edema", sentence=10114, chars=[40,44], words=[5,5])),
#   ChemicalDisease(Span("amlodipine", sentence=10114, chars=[172,181], words=[36,36]), Span("edema", sentence=10114, chars=[40,44], words=[5,5])),
#   ChemicalDisease(Span("amlodipine", sentence=10114, chars=[211,220], words=[45,45]), Span("edema", sentence=10114, chars=[40,44], words=[5,5])),
#   ChemicalDisease(Span("amlodipine)", sentence=10114, chars=[239,249], words=[52,53]), Span("edema", sentence=10114, chars=[40,44], words=[5,5])),
#   ChemicalDisease(Span("adrenaline", sentence=9356, chars=[73,82], words=[12,12]), Span("bradycardia", sentence=9356, chars=[13,23], words=[3,3])),
#   ChemicalDisease(Span("tramadol", sentence=8345, chars=[56,63], words=[7,7]), Span("hallucinations", sentence=8345, chars=[15,28], words=[2,2])),
#   ChemicalDisease(Span("warfarin", sentence=7095, chars=[129,136], words=[21,21]), Span("LV Cutaneous lesions", sentence=7095, chars=[77,96], words=[13,15])),
#   ChemicalDisease(Span("etoposide", sentence=9942, chars=[102,110], words=[14,14]), Span("weight loss", sentence=9942, chars=[244,254], words=[34,35])),
#   ChemicalDisease(Span("etoposide", sentence=9945, chars=[90,98], words=[13,13]), Span("hematologic toxicity", sentence=9945, chars=[166,185], words=[24,25])),
#   ChemicalDisease(Span("ouabain", sentence=8301, chars=[132,138], words=[19,19]), Span("arrhythmic", sentence=8301, chars=[71,80], words=[9,9])),
#   ChemicalDisease(Span("nitric oxide", sentence=8573, chars=[26,37], words=[5,6]), Span("headache", sentence=8573, chars=[52,59], words=[11,11])),
#   ChemicalDisease(Span("azole", sentence=7265, chars=[148,152], words=[22,22]), Span("Prolongation of QT interval", sentence=7265, chars=[0,26], words=[0,3])),
#   ChemicalDisease(Span("azole", sentence=7265, chars=[148,152], words=[22,22]), Span("sudden cardiac death", sentence=7265, chars=[54,73], words=[10,12])),
#   ChemicalDisease(Span("azole", sentence=7265, chars=[148,152], words=[22,22]), Span("torsades de pointes", sentence=7265, chars=[29,47], words=[5,7])),
#   ChemicalDisease(Span("erythromycin", sentence=7265, chars=[132,143], words=[20,20]), Span("Prolongation of QT interval", sentence=7265, chars=[0,26], words=[0,3])),
#   ChemicalDisease(Span("erythromycin", sentence=7265, chars=[132,143], words=[20,20]), Span("sudden cardiac death", sentence=7265, chars=[54,73], words=[10,12])),
#   ChemicalDisease(Span("erythromycin", sentence=7265, chars=[132,143], words=[20,20]), Span("torsades de pointes", sentence=7265, chars=[29,47], words=[5,7])),
#   ChemicalDisease(Span("dobutamine", sentence=8582, chars=[56,65], words=[8,8]), Span("coronary artery spasm", sentence=8582, chars=[27,47], words=[4,6])),
#   ChemicalDisease(Span("apomorphine", sentence=7794, chars=[379,389], words=[61,61]), Span("dyskinesia", sentence=7794, chars=[56,65], words=[9,9])),
#   ChemicalDisease(Span("apomorphine", sentence=7794, chars=[379,389], words=[61,61]), Span("dyskinesia", sentence=7794, chars=[312,321], words=[52,52])),
#   ChemicalDisease(Span("methamphetamine", sentence=6257, chars=[114,128], words=[18,18]), Span("Aggressive behaviors", sentence=6257, chars=[0,19], words=[0,1])),
#   ChemicalDisease(Span("methamphetamine", sentence=6257, chars=[114,128], words=[18,18]), Span("psychiatric disorders", sentence=6257, chars=[73,93], words=[11,12])),
#   ChemicalDisease(Span("METH)", sentence=6257, chars=[131,135], words=[20,21]), Span("Aggressive behaviors", sentence=6257, chars=[0,19], words=[0,1])),
#   ChemicalDisease(Span("METH)", sentence=6257, chars=[131,135], words=[20,21]), Span("psychiatric disorders", sentence=6257, chars=[73,93], words=[11,12])),
#   ChemicalDisease(Span("azathioprine", sentence=8975, chars=[192,203], words=[28,28]), Span("cholestasis", sentence=8975, chars=[151,161], words=[22,22])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=8906, chars=[89,104], words=[20,20]), Span("bladder cancer", sentence=8906, chars=[117,130], words=[22,23])),
#   ChemicalDisease(Span("dobutamine", sentence=8592, chars=[29,38], words=[4,4]), Span("coronary spastic angina", sentence=8592, chars=[89,111], words=[13,15])),
#   ChemicalDisease(Span("dobutamine", sentence=8592, chars=[29,38], words=[4,4]), Span("coronary spasm", sentence=8592, chars=[52,65], words=[7,8])),
#   ChemicalDisease(Span("cis-RA", sentence=8230, chars=[62,67], words=[11,11]), Span("hypercalcemia", sentence=8230, chars=[17,29], words=[3,3])),
#   ChemicalDisease(Span("doxorubicin", sentence=9942, chars=[292,302], words=[43,43]), Span("weight loss", sentence=9942, chars=[68,78], words=[9,10])),
#   ChemicalDisease(Span("doxorubicin", sentence=9942, chars=[292,302], words=[43,43]), Span("weight loss", sentence=9942, chars=[244,254], words=[34,35])),
#   ChemicalDisease(Span("daunorubicin", sentence=9942, chars=[85,96], words=[12,12]), Span("weight loss", sentence=9942, chars=[68,78], words=[9,10])),
#   ChemicalDisease(Span("daunorubicin", sentence=9942, chars=[85,96], words=[12,12]), Span("weight loss", sentence=9942, chars=[244,254], words=[34,35])),
#   ChemicalDisease(Span("etoposide", sentence=9942, chars=[102,110], words=[14,14]), Span("weight loss", sentence=9942, chars=[68,78], words=[9,10])),
#   ChemicalDisease(Span("methadone", sentence=9462, chars=[306,314], words=[53,53]), Span("syncope", sentence=9462, chars=[106,112], words=[17,17])),
#   ChemicalDisease(Span("paracetamol", sentence=8415, chars=[31,41], words=[4,4]), Span("urticaria/angioedema", sentence=8415, chars=[74,93], words=[9,9])),
#   ChemicalDisease(Span("nimesulide", sentence=8415, chars=[16,25], words=[2,2]), Span("urticaria/angioedema", sentence=8415, chars=[74,93], words=[9,9])),
#   ChemicalDisease(Span("propofol", sentence=7636, chars=[29,36], words=[6,6]), Span("postoperative delirium", sentence=7636, chars=[75,96], words=[12,13])),
#   ChemicalDisease(Span("steroid", sentence=7980, chars=[31,37], words=[4,4]), Span("septal rupture", sentence=7980, chars=[77,90], words=[9,10])),
#   ChemicalDisease(Span("cocaine-induced", sentence=7337, chars=[201,215], words=[30,30]), Span("psychotic symptoms", sentence=7337, chars=[92,109], words=[13,14])),
#   ChemicalDisease(Span("amphetamine", sentence=7337, chars=[185,195], words=[27,27]), Span("psychotic symptoms", sentence=7337, chars=[92,109], words=[13,14])),
#   ChemicalDisease(Span("amphetamine", sentence=7337, chars=[185,195], words=[27,27]), Span("psychosis", sentence=7337, chars=[217,225], words=[31,31])),
#   ChemicalDisease(Span("amphetamine", sentence=7338, chars=[19,29], words=[2,2]), Span("hyperkinesia", sentence=7338, chars=[100,111], words=[13,13])),
#   ChemicalDisease(Span("Methamphetamine", sentence=7338, chars=[0,14], words=[0,0]), Span("hyperkinesia", sentence=7338, chars=[100,111], words=[13,13])),
#   ChemicalDisease(Span("dobutamine", sentence=10073, chars=[81,90], words=[13,13]), Span("hypersensitivity", sentence=10073, chars=[22,37], words=[5,5])),
#   ChemicalDisease(Span("dobutamine", sentence=10073, chars=[81,90], words=[13,13]), Span("myocarditis", sentence=10073, chars=[54,64], words=[9,9])),
#   ChemicalDisease(Span("levodopa-induced", sentence=10504, chars=[122,137], words=[20,20]), Span("dyskinesias", sentence=10504, chars=[139,149], words=[21,21])),
#   ChemicalDisease(Span("oral contraceptives", sentence=6463, chars=[70,88], words=[10,11]), Span("liver tumors", sentence=6463, chars=[41,52], words=[6,7])),
#   ChemicalDisease(Span("doxorubicin", sentence=9940, chars=[288,298], words=[41,41]), Span("hematologic toxicity", sentence=9940, chars=[58,77], words=[10,11])),
#   ChemicalDisease(Span("daunorubicin", sentence=9940, chars=[270,281], words=[38,38]), Span("hematologic toxicity", sentence=9940, chars=[58,77], words=[10,11])),
#   ChemicalDisease(Span("etoposide", sentence=9940, chars=[259,267], words=[36,36]), Span("hematologic toxicity", sentence=9940, chars=[58,77], words=[10,11])),
#   ChemicalDisease(Span("Oral Contraceptives", sentence=6465, chars=[46,64], words=[7,8]), Span("Liver Tumors", sentence=6465, chars=[17,28], words=[3,4])),
#   ChemicalDisease(Span("oxacillin", sentence=9922, chars=[39,47], words=[7,7]), Span("renal failure", sentence=9922, chars=[117,129], words=[18,19])),
#   ChemicalDisease(Span("diazepam", sentence=9358, chars=[13,20], words=[3,3]), Span("bradycardia", sentence=9358, chars=[63,73], words=[8,8])),
#   ChemicalDisease(Span("nicotine", sentence=9962, chars=[138,145], words=[22,22]), Span("catalepsy", sentence=9962, chars=[31,39], words=[5,5])),
#   ChemicalDisease(Span("morphine", sentence=9962, chars=[118,125], words=[19,19]), Span("catalepsy", sentence=9962, chars=[31,39], words=[5,5])),
#   ChemicalDisease(Span("imipenem/cilastatin", sentence=10409, chars=[179,197], words=[30,30]), Span("seizures", sentence=10409, chars=[137,144], words=[24,24])),
#   ChemicalDisease(Span("tramadol", sentence=8348, chars=[152,159], words=[21,21]), Span("hallucinations", sentence=8348, chars=[71,84], words=[10,10])),
#   ChemicalDisease(Span("aconitine-induced", sentence=8296, chars=[118,134], words=[19,19]), Span("arrhythmia", sentence=8296, chars=[171,180], words=[25,25])),
#   ChemicalDisease(Span("cefotetan", sentence=9789, chars=[67,75], words=[9,9]), Span("hemolytic anemia", sentence=9789, chars=[14,29], words=[2,3])),
#   ChemicalDisease(Span("cefotetan", sentence=9791, chars=[108,116], words=[18,18]), Span("hemolytic anemias", sentence=9791, chars=[56,72], words=[10,11])),
#   ChemicalDisease(Span("fentanyl", sentence=9631, chars=[164,171], words=[25,25]), Span("rigidity", sentence=9631, chars=[28,35], words=[4,4])),
#   ChemicalDisease(Span("adrenaline-induced", sentence=9357, chars=[86,103], words=[14,14]), Span("bradycardia", sentence=9357, chars=[163,173], words=[23,23])),
#   ChemicalDisease(Span("adrenaline-induced", sentence=9357, chars=[137,154], words=[21,21]), Span("bradycardia", sentence=9357, chars=[163,173], words=[23,23])),
#   ChemicalDisease(Span("diazepam", sentence=9357, chars=[42,49], words=[6,6]), Span("bradycardia", sentence=9357, chars=[163,173], words=[23,23])),
#   ChemicalDisease(Span("nicotine", sentence=9956, chars=[33,40], words=[7,7]), Span("catalepsy", sentence=9956, chars=[45,53], words=[9,9])),
#   ChemicalDisease(Span("carbamazepine", sentence=6793, chars=[217,229], words=[26,26]), Span("atrioventricular conduction delay", sentence=6793, chars=[126,158], words=[15,17])),
#   ChemicalDisease(Span("carbamazepine", sentence=6793, chars=[217,229], words=[26,26]), Span("bradyarrhythmias", sentence=6793, chars=[106,121], words=[13,13])),
#   ChemicalDisease(Span("steroid", sentence=7979, chars=[80,86], words=[11,11]), Span("ventricular septal rupture", sentence=7979, chars=[28,53], words=[4,6])),
#   ChemicalDisease(Span("oxacillin", sentence=9921, chars=[54,62], words=[5,5]), Span("Cutaneous leucocytoclastic vasculitis", sentence=9921, chars=[0,36], words=[0,2])),
#   ChemicalDisease(Span("nicotine", sentence=9959, chars=[154,161], words=[22,22]), Span("catalepsy", sentence=9959, chars=[102,110], words=[14,14])),
#   ChemicalDisease(Span("Lithium", sentence=6594, chars=[0,6], words=[0,0]), Span("tremor", sentence=6594, chars=[75,80], words=[14,14])),
#   ChemicalDisease(Span("Lithium", sentence=6594, chars=[0,6], words=[0,0]), Span("tremor", sentence=6594, chars=[125,130], words=[27,27])),
#   ChemicalDisease(Span("Lithium", sentence=6594, chars=[0,6], words=[0,0]), Span("tremor", sentence=6594, chars=[222,227], words=[46,46])),
#   ChemicalDisease(Span("lithium", sentence=6594, chars=[168,174], words=[36,36]), Span("tremor", sentence=6594, chars=[75,80], words=[14,14])),
#   ChemicalDisease(Span("lithium", sentence=6594, chars=[168,174], words=[36,36]), Span("tremor", sentence=6594, chars=[125,130], words=[27,27])),
#   ChemicalDisease(Span("lithium", sentence=6594, chars=[168,174], words=[36,36]), Span("tremor", sentence=6594, chars=[222,227], words=[46,46])),
#   ChemicalDisease(Span("lithium", sentence=6594, chars=[251,257], words=[50,50]), Span("tremor", sentence=6594, chars=[75,80], words=[14,14])),
#   ChemicalDisease(Span("lithium", sentence=6594, chars=[251,257], words=[50,50]), Span("tremor", sentence=6594, chars=[125,130], words=[27,27])),
#   ChemicalDisease(Span("lithium", sentence=6594, chars=[251,257], words=[50,50]), Span("tremor", sentence=6594, chars=[222,227], words=[46,46])),
#   ChemicalDisease(Span("doxorubicin", sentence=7997, chars=[99,109], words=[20,20]), Span("Proteinuria", sentence=7997, chars=[0,10], words=[0,0])),
#   ChemicalDisease(Span("DX", sentence=7997, chars=[187,188], words=[33,33]), Span("Proteinuria", sentence=7997, chars=[0,10], words=[0,0])),
#   ChemicalDisease(Span("BHA", sentence=6134, chars=[19,21], words=[5,5]), Span("forestomach tumors", sentence=6134, chars=[211,228], words=[37,38])),
#   ChemicalDisease(Span("cyclophosphamide", sentence=6167, chars=[72,87], words=[9,9]), Span("Hemorrhagic cystitis", sentence=6167, chars=[0,19], words=[0,1])),
#   ChemicalDisease(Span("methadone", sentence=9467, chars=[48,56], words=[9,9]), Span("syncope", sentence=9467, chars=[80,86], words=[14,14])),
#   ChemicalDisease(Span("dobutamine", sentence=8585, chars=[107,116], words=[19,19]), Span("coronary spasm", sentence=8585, chars=[78,91], words=[14,15])),
#   ChemicalDisease(Span("metrizoate", sentence=6430, chars=[132,141], words=[27,27]), Span("ventricular fibrillation", sentence=6430, chars=[15,38], words=[2,3])),
#   ChemicalDisease(Span("fentanyl", sentence=9630, chars=[30,37], words=[3,3]), Span("rigidity", sentence=9630, chars=[15,22], words=[1,1])),
#   ChemicalDisease(Span("phenytoin", sentence=10162, chars=[10,18], words=[1,1]), Span("bradycardia", sentence=10162, chars=[71,81], words=[9,9])),
#   ChemicalDisease(Span("D-Penicillamine", sentence=9377, chars=[0,14], words=[0,0]), Span("nephrotic syndrome", sentence=9377, chars=[23,40], words=[2,3])),
#   ChemicalDisease(Span("D-Penicillamine", sentence=9377, chars=[0,14], words=[0,0]), Span("proteinuria", sentence=9377, chars=[77,87], words=[10,10])),
#   ChemicalDisease(Span("azathioprine", sentence=8973, chars=[55,66], words=[7,7]), Span("cholestasis", sentence=8973, chars=[11,21], words=[1,1])),
#   ChemicalDisease(Span("azathioprine", sentence=8973, chars=[55,66], words=[7,7]), Span("bile duct injury", sentence=8973, chars=[28,43], words=[3,5])),
#   ChemicalDisease(Span("GTN", sentence=8575, chars=[66,68], words=[9,9]), Span("headache-free", sentence=8575, chars=[100,112], words=[17,17])),
#   ChemicalDisease(Span("Diazepam", sentence=9353, chars=[0,7], words=[0,0]), Span("bradycardia", sentence=9353, chars=[28,38], words=[3,3])),
#   ChemicalDisease(Span("propofol", sentence=7630, chars=[256,263], words=[42,42]), Span("delirium", sentence=7630, chars=[165,172], words=[29,29]))})

# %%
L_dev.lf_stats(session, L_gold_dev, gen_model.weights.lf_accuracy())
